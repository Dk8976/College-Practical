# %% [markdown]
# <a href="https://colab.research.google.com/github/Dk8976/College-Practical/blob/main/KK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install contextily
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 83.4 MB/s eta 0:00:00
# ...

# %%
import geopandas
path_to_data=geopandas.datasets.get_path('nybb')
gdf=geopandas.read_file(path_to_data)
gdf=gdf.set_index('BoroName')
gdf['area']=gdf.area
gdf['area']
# Out:
# <ipython-input-7-8707d8be0d4b>:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'nybb' data from the geodatasets package.
#
# from geodatasets import get_path
# path_to_file = get_path('nybb')
#
#   path_to_data=geopandas.datasets.get_path('nybb')
# BoroName
# Staten Island    1.623822e+09
# Queens           3.045214e+09
# Brooklyn         1.937478e+09
# Manhattan        6.364712e+08
# Bronx            1.186926e+09
# Name: area, dtype: float64

# %%
gdf.plot('area',legend=True)
gdf['centroid']=gdf.centroid
gdf=gdf.set_geometry('centroid')
gdf.plot('area',legend=True)
# Out:
# <Axes: >

# %%
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt
from shapely.geometry import Point,LineString,Polygon
from matplotlib import pyplot as plt

# %%
data=gpd.read_file('polbnda_ind.shp')
data.head()
# Out:
#   f_code  coc                nam               laa       pop  ypc adm_code  \
# 0  FA001  IND  JAMMU AND KASHMIR            GILGIT -99999999    0      UNK
# 1  FA001  IND  JAMMU AND KASHMIR  TRIBAL TERRITORY -99999999    0      UNK
# 2  FA001  IND  JAMMU AND KASHMIR    GILGIT WAZARAT -99999999    0      UNK
# 3  FA001  IND  JAMMU AND KASHMIR            CHILAS -99999999    0      UNK
# 4  FA001  IND  JAMMU AND KASHMIR      MUZAFFARABAD -99999999    0      UNK
#
#   salb  soc                                           geometry
# 0  UNK  IND  POLYGON Z ((74.73719 37.02695 0.00000, 74.7445...
# 1  UNK  IND  POLYGON Z ((73.13781 35.81256 0.00000, 73.1441...
# 2  UNK  IND  POLYGON Z ((75.13574 34.89415 0.00000, 75.0727...
# 3  UNK  IND  POLYGON Z ((74.18809 35.66722 0.00000, 74.2342...
# 4  UNK  IND  POLYGON Z ((74.08553 35.07817 0.00000, 74.0961...

# %%
ax=data.plot(figsize = (10,10),legend=True)
ctx.add_basemap(ax,crs=data.crs,source=ctx.providers.OpenStreetMap.Mapnik)

# %%
ax=data.plot(figsize = (10,10),legend=True)
ctx.add_basemap(ax,crs=data.crs,source=ctx.providers.Stamen.Terrain)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/xyzservices/lib.py in __getattr__(self, key)
#      43         try:
# ---> 44             return self.__getitem__(key)
#      45         except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-1c80023008b6> in <cell line: 2>()
#       1 ax=data.plot(figsize = (10,10),legend=True)
# ----> 2 ctx.add_basemap(ax,crs=data.crs,source=ctx.providers.Stamen.Terrain)
#
# /usr/local/lib/python3.10/dist-packages/xyzservices/lib.py in __getattr__(self, key)
#      44             return self.__getitem__(key)
#      45         except KeyError as err:
# ---> 46             raise AttributeError(key) from err
#      47
# ...
